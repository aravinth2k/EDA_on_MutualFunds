# %%
# Import all Required Libraries
import pandas as pd
import re

# %% [markdown]
# ### Loading the Data

# %%
# Read data from a csv file
mf = pd.read_csv('MF_Data.csv')

# %%
mf.head()
# Out:
#            AMC Name           AMC Launch Date  Rank  \
# 0           ESCORTS  1996-04-15T00:00:00.822Z  34.0
# 1          RELIANCE  1995-06-30T00:00:00.684Z   6.0
# 2           ESCORTS  1996-04-15T00:00:00.459Z  34.0
# 3  ICICI_PRUDENTIAL  1993-10-12T00:00:00.628Z   3.0
# 4              HSBC  2002-05-27T00:00:00.707Z  21.0
#
#                                     Mutual Fund Name           AUM    Type  \
# 0            Quant Small Cap Fund Direct Plan Growth   5565.264021  Equity
# 1         Nippon India Small Cap Fund Direct  Growth  31945.148000  Equity
# 2            Quant Infrastructure Fund Direct Growth    924.574701  Equity
# 3  ICICI Prudential Commodities Fund Direct   Growth    994.134033  Equity
# 4                  HSBC Small Cap Fund Direct Growth  10129.408282  Equity
#
#   Scheme Launch Date                                          Exit Load  \
# 0        07-Jan-2013          Exit load of 1% if redeemed within 1 year
# 1        31-Dec-2012      Exit load of 1% if redeemed within one month.
# 2        07-Jan-2013    Exit load of 0.50% if redeemed within 3 months.
# 3        15-Oct-2019       Exit load of 1% if redeemed within 3 months.
# 4        12-May-2014  For units in excess of 10% of the investment,1...
#
#    Expense Ratio      Investment Type  ...  Minimum Investment  \
# 0           0.62            Small Cap  ...                5000
# 1           0.75            Small Cap  ...                5000
# 2           0.64  Sectoral / Thematic  ...                5000
# 3           1.06  Sectoral / Thematic  ...                5000
# 4           0.73            Small Cap  ...                5000
#
#    Minimum SIP Amount  Total Return  1m_return  1y_return  2y_return  \
# 0              1000.0    433.995802   7.212296  42.029294  40.335026
# 1               100.0   1043.195148   6.097628  37.840897  51.430616
# 2              1000.0    405.316648   6.683960  21.283722  46.701603
# 3               100.0    214.800000   4.968323  30.622407  25.518341
# 4              1000.0    521.505000   5.097216  32.283798  46.487740
#
#     3y_return   4y_return   5y_return   10y_return
# 0  283.355608  324.014833  251.597822   414.830298
# 1  223.395720  225.251920  187.826655  1273.914846
# 2  240.254070  204.645633  211.893923   616.427861
# 3  219.269777         NaN         NaN          NaN
# 4  209.226467  168.903109  130.619235          NaN
#
# [5 rows x 21 columns]

# %%
mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AMC Name            1167 non-null   object
#  1   AMC Launch Date     1166 non-null   object
#  2   Rank                1141 non-null   float64
#  3   Mutual Fund Name    1169 non-null   object
#  4   AUM                 1158 non-null   float64
#  5   Type                1169 non-null   object
#  6   Scheme Launch Date  1167 non-null   object
#  7   Exit Load           1169 non-null   object
#  8   Expense Ratio       1144 non-null   float64
#  9   Investment Type     1169 non-null   object
#  10  NAV                 1169 non-null   float64
#  11  Minimum Investment  1169 non-null   int64
#  12  Minimum SIP Amount  1160 non-null   float64
#  13  Total Return        1139 non-null   float64
#  14  1m_return           1133 non-null   float64
#  15  1y_return           1027 non-null   float64
#  16  2y_return           939 non-null    float64
#  17  3y_return           866 non-null    float64
#  18  4y_return           808 non-null    float64
#  19  5y_return           713 non-null    float64
#  20  10y_return          534 non-null    float64
# dtypes: float64(13), int64(1), object(7)
# memory usage: 191.9+ KB

# %%
# Check Duplicate Values
mf[mf.duplicated()].shape
# Out:
# (56, 21)

# %% [markdown]
# ### Remove Duplicates

# %%
mf.drop_duplicates(inplace=True)

# %%
mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1113 entries, 0 to 1168
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AMC Name            1111 non-null   object
#  1   AMC Launch Date     1110 non-null   object
#  2   Rank                1086 non-null   float64
#  3   Mutual Fund Name    1113 non-null   object
#  4   AUM                 1102 non-null   float64
#  5   Type                1113 non-null   object
#  6   Scheme Launch Date  1111 non-null   object
#  7   Exit Load           1113 non-null   object
#  8   Expense Ratio       1092 non-null   float64
#  9   Investment Type     1113 non-null   object
#  10  NAV                 1113 non-null   float64
#  11  Minimum Investment  1113 non-null   int64
#  12  Minimum SIP Amount  1104 non-null   float64
#  13  Total Return        1083 non-null   float64
#  14  1m_return           1077 non-null   float64
#  15  1y_return           1003 non-null   float64
#  16  2y_return           933 non-null    float64
#  17  3y_return           866 non-null    float64
#  18  4y_return           808 non-null    float64
#  19  5y_return           713 non-null    float64
#  20  10y_return          534 non-null    float64
# dtypes: float64(13), int64(1), object(7)
# memory usage: 191.3+ KB

# %% [markdown]
# ### Extract Exit load percentage and duration from Text

# %%
mf['Exit Load'].unique()
# Out:
# array(['Exit load of 1% if redeemed within 1 year',
#        'Exit load of 1% if redeemed within one month.',
#        'Exit load of 0.50% if redeemed within 3 months.',
#        'Exit load of 1% if redeemed within 3 months.',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 1 year.',
#        'Exit load of 1% if redeemed within 15 days',
#        'For units more than 12% of the investments, an exit load of 1% if redeemed within 12 months.',
#        'Exit load of 1% if redeemed upto 1 year',
#        'Exit load of 1%, if redeemed within 30 days.',
#        'Exit load of 1% if redeemed within 1 year.',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 365 days',
#        'Exit load of 1%, if redeemed within 90 days.',
#        'Exit load of 1% if redeemed within 1 year for units beyond 10% of the investment.',
#        'If unit beyond 10%, Exit load of 1% if redeemed within 1 year.',
#        'Exit load of 1% if redeemed within 90 days.',
#        'Exit load of 1% if redeemed less than 12 months',
#        'For units more than 25% of the investments, an exit load of 1% if redeemed within 365 days.',
#        'For units more than 10% of the investments, an exit load of 1% if redeemed within 12 months.',
#        'Exit load of 0.25% if redeemed within 30 days.', 'Nil',
#        'Exit load of 1% if redeemed within 30 days.',
#        'Exit load of 1% if redeemed within 12 months.',
#        'For units in excess of 10% of the investment, 1% will be charged for redemption within 1 year.',
#        '1% exit load if redeemed within 15 days.',
#        'Exit load of 1% for investments beyond 10% if redeemed within 12 months',
#        'Exit load of 0.10% if redeemed within 30 days.',
#        'Exit load of 1% if redeemed within 1 month.',
#        'Exit load of 1% if redeemed within 1 year.\r\nSame for SIP.',
#        'Exit load of 1%, if redeemed within 1 year.',
#        '1% for redemption within 90 days',
#        'For units more than 10% of the investments, an exit load of 1% if redeemed within 1 year.',
#        '0.5% for redemption within 90 days',
#        'Exit load of 1% if redeemed within 1 months',
#        'Exit load of 1%, if redeemed within 1 month.',
#        'Exit Load for units in excess of 12% of the investment,1% will be charged for redemption within 90 days.',
#        'Exit load of 0.50% if redeemed within 30 days.',
#        'For units more than 12% of the investments, an exit load of 1% if redeemed within 365 days.',
#        'Exit load of 1% if redeemed less than 1 year',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 12 months',
#        'Exit load of 1% if redeemed within 7 days.',
#        'Exit load of 1% if redeemed within 12 months',
#        'If unit beyond 10%, exit load of 1% if redeemed within 1 year.',
#        'Exit load of 1%, if redeemed within 15 days.',
#        'Exit load of 1%, if redeemed within 3 months.',
#        'For units in excess of 30% of the investment,1% will be charged for redemption within 365 days',
#        'Exit load of 1%, if redeemed within 12 months.',
#        'For units in excess of 15% of the investment, 1% will be charged for redemption within 1 year.',
#        'Exit load of 1% if redeemed within 365 days.',
#        'Exit load of 0.50% if redeemed within 15 days',
#        'Exit load of 1% if redeemed within 15 days.',
#        'Exit load of 0.5%, if redeemed within 7 days.',
#        'For units in excess of 10% of the investment, 1% will be charged for redemption within 12 months.',
#        'For units in excess of 12% of the investment,1% will be charged for redemption within 365 Days.',
#        'For units more than 12% of the investments, an exit load of 1% if redeemed within 90 days',
#        'For units in excess of 25% of the investment,1% will be charged for redemption within 365 days.',
#        '1% for redemption within 30 days',
#        'For units above 10% of the investment, exit load of 2% if redeemed within 365 days and 1% if redeemed after 365 days but on or before 730 days.',
#        'Exit load of 2% if redeemed within 6 months.',
#        'Exit load of 0.50% if redeemed within 90 days.',
#        'Exit load of 0.25% if redeemed within 1 month',
#        'Exit load of 1% if redeemed upto 1 year.',
#        'Exit load of 0.25% if redeemed within 7 days.',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 12 months.',
#        'For more than 10% of investments 1% will be charged if redeemed within 1 year',
#        'For units in excess of 8% of the investment,1% will be charged for redemption within 365 days',
#        'For units more than 10% of the investments, an exit load of 1% if redeemed within 3 months.',
#        'Exit Load for units in excess of 10% of the investment,1% will be charged for redemption within 90 days.',
#        'For units in excess of 10% of the investment, exit load of 2% if redeemed within 365 days, 1% if redeemed after 365 days but within 730 days.',
#        '1% for redemption within 60 days',
#        'Exit load of 1% if redeemed within 365 Days.',
#        'For units in excess of 24% of the investment,1% will be charged for redemption within 365 days',
#        'Exit load of 1% if units in excess of 10% are redeemed or switched-out within 12 months',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within one year.',
#        'For more than 15% of investments 1% will be charged if redeemed within 1 year',
#        'Exit Load for units in excess of 10% of the investment,1% will be charged for redemption within 12 months.',
#        'Exit load of 1% if redeemed within 12 months for units beyond 10% of the investment.',
#        'For units more than 10% of the investments, an exit load of 1% if redeemed within 365 days.',
#        'Exit load of 0.5% if redeemed within 15 days.',
#        'Exit load of 0.25% if redeemed within 3 days',
#        'Exit load of 0.20% if redeemed within 15 days',
#        'Exit load of 0.25% if redeemed within 7 days',
#        'For units in excess of 25% of the investment,1% will be charged for redemption within 1 year.',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within one month.',
#        'An exit load of 1% if more than 10% of units are redeemed within 12 months.',
#        'Exit load of 1% if units in excess of 10% are redeemed or switched-out within 12 months.',
#        'Exit load of 0.25%, if redeemed within 7 days.',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 365 days.',
#        'For units in excess of 10% of the investment, 1% will be charged for redemption within 1 year',
#        'For units in excess of 15% of the investment,1% will be charged for redemption within 365 days',
#        'Exit load of 1%, if redeemed within 3 months',
#        'Exit load of 1%, if redeemed within 7 days.',
#        'For units in excess of 25% of the investment,1% will be charged for redemption within 365 days',
#        'Exit load of 1% if redeemed before 61 months.',
#        'For more than 10% of investments 1% will be charged if redeemed within 12 months',
#        'Exit load of 1% will be charged for any redemption more than 10% of units allotted are redeemed within 1 year.',
#        'For units in excess of 10% of the investment, exit load of 1% if redeemed within 1 year.',
#        'Exit load of 1% if units in excess of 10% are redeemed or switched-out within 1 year',
#        'For redemption in excess of 15% of the units, 1% will be charged if redeemed within 12 months.',
#        'For units in excess of 12% of the investment,1% will be charged for redemption within 90 days',
#        'Exit Load for units in excess of 30% of the investment,1% will be charged for redemption within 1 year.',
#        'For units more than 10% of the allotted, an exit load of 1% will be charged if redeemed within 12 months.',
#        '0.25% for redemption within 7 days.',
#        'For more than 10% of investments 1% will be charged if redeemed within 12 month',
#        'Exit load of 1% if redeemed within 3 years.',
#        'For units in excess of 10% of the investment, 1% will be charged for redemption within 12 months',
#        'For units more than 12% of the allotted, an exit load of 1% will be charged if redeemed within 365 days',
#        'For units in excess of 15% of the investment,1% will be charged for redemption within 3 months.',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 15 days.',
#        'For units in excess of 0.50% of the investment,1% will be charged for redemption within 1 month.',
#        'Exit load of 1% if redeemed within 1 year for units above 15% of the investment.',
#        'Exit load of 1% if units in excess of 10% of the initial units allotted are redeemed within 1 year',
#        'For units in excess of 15% of the investment, exit load of 2% if redeemed within 1 year, 1% if redeemed after 1 year but within 2 years.',
#        'Exit Load of 3% if redeemed within an year, 2% if redeemed within 2 years and 1% if redeemed within  3 years',
#        'Exit load of 0.10% if redeemed within 15 days.',
#        'For units in excess of 10% of the investment, 0.25% will be charged for redemption within 3 months.',
#        'Exit load of 1% if redeemed within 1 month',
#        'For units in excess of 8% of the investment,1% will be charged for redemption within 6 months.',
#        'Exit Load for units in excess of 12% of the investment,1% will be charged for redemption within 365 days.',
#        'For units in excess of 15% of the investment, 1% will be charged for redemption within 1 year',
#        'For units in excess of 8% of the investment,1% will be charged for redemption within 90 days.',
#        '0.25% for redemption within 28 days',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 1 months.',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within one year',
#        '0.25% for redemption within 7 days',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 1 month.',
#        'Exit load of 1% if redeemed within 1 months.',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 1 year',
#        'For units in excess of 10% of the investment,1% will be charged for redemption within 3 months.',
#        'Exit load of 0.75% if redeemed within 1 year',
#        'For units in excess of 10% of the investment,0.25% will be charged for redemption within 7 days',
#        'Exit load of 1% if redeemed within 12 months.\r\nSame for SIP.',
#        'For units more than 12% of the investments, an exit load of 0.25% if redeemed within 90 days.',
#        'Exit load of 1% if units in excess of 10% are redeemed within 12 months',
#        'Exit load of 3% if redeemed before the age of 58 yrs.',
#        '1% for redemption within 30 days.',
#        'Exit load of 1%, if redeemed within 90 days',
#        'For units in excess of 10% of the investment, 0.25% will be charged for redemption within 7 days',
#        'Exit load of 1% if redeemed within 90 days',
#        'Exit load of 0.25% if redeemed within 1 month.',
#        'Exit load of 1% if redeemed within one year.',
#        'For units in excess of 12% of the investment,1% will be charged for redemption within 365 days',
#        'For units in excess of 15% of the investment, exit load of 3% if redeemed within 1 year, 2% if redeemed after 1 year but within 2 years, 1% if redeemed after 2 years but within 3 years.',
#        'Exit load of 1% if redeemed within 6 months',
#        'For units more than 10% of the investments, an exit load of 1% if redeemed within one year.',
#        'For units in excess of 15% of the investment, 1% will be charged for redemption within 12 months and 0.50% if redeemed after 12 months but within 18 months',
#        'For units in excess of 8% of the investment, exit load of 3% if redeemed within 12 months, 1.5% if redeemed after 12 months but within 24 months and 0.75% if redeemed after 24 months but within 36 months',
#        'Exit load of 0.50% if units in excess of 15% are redeemed or switched-out within 90 days',
#        'Exit load of 1% will be charged on investment in excess of 10% if redeemed within 12 months.',
#        'Exit Load for units in excess of 10% of the investment, 3% will be charged for redemption within 1 year and 2% if redeemed after 1 year upto 2 year.',
#        'Exit load of 4%, if redeemed within 1 year.',
#        'For units in excess of 8% of the investment,1.50% will be charged for redemption within 12 months',
#        'For units in excess of 24% of the investment,1% will be charged for redemption within 365 days.',
#        'Exit load of 0.25% if redeemed within 15 days.',
#        'For units in excess of 10% of the investment, exit load of 1% if redeemed within 12 months.',
#        'Exit load of 0.25% if redeemed within 30 days',
#        'For units in excess of 6% of the investment,1% will be charged for redemption within 365 days',
#        'Exit load of 0.1%, if redeemed within 30 days.',
#        '0.25%  if redeemed within 30 days.',
#        '0.25% for redemption within 15 days',
#        'Exit load of 0.25%, if redeemed within 1 month.',
#        'Exit load of 0.0070% if redeemed within 1 day, 0.0065% if redeemed within 2 days, 0.0060% if redeemed within 3 days, 0.0055% if redeemed within 4 days, 0.0050% if redeemed within 5 days, 0.0045% if redeemed within 6 days.',
#        'For units in excess of 10% of the investment, 0.25% will be charged for redemption within 21 days.',
#        'Exit load 0.10% if redeemed within 30 days.',
#        '0.25% exit load if redeemed within 30 days.',
#        'Exit load of 0.50% if redeemed within 1 month',
#        'For units in excess of 10% of the investment, 0.25% will be charged for redemption within 1 month',
#        'Exit load of 0.10% if redeemed within 3 days',
#        'For units more than 10% of the investments, an exit load of 0.25% if redeemed within 30 days.',
#        'Exit load of 0.25% if redeemed within 1 months.',
#        'Exit load 0.10%, If redeemed within 30 days',
#        'Exit load of 0.25% if redeemed within 15 days',
#        'Exit load of 0.50% if redeeemed within 3 months',
#        'Exit load 0.1%, if redeemed within 30 days',
#        '0.50% for redemption within 30 days',
#        'Exit load of 0.50% if redeemed within 90 days',
#        'Exit load of 1.00% if amount is redeemed / switched out within 12 months from the date of allotment.',
#        'Exit load of 0.25%, if redeemed within 30 days.',
#        'Exit Load for units in excess of 20% of the investment,1% will be charged for redemption within 12 months.',
#        'For units in excess of 10% of the investment, 1% will be charged for redemption within 365 days',
#        'Exit load of 0.25% if redeemed within 1 months',
#        'Exit load of 1%, if redeemed within 15 days',
#        'Exit load of 0.15%, if redeemed within 30 days',
#        'Exit load of 0.05% if redeemed within 5 days.',
#        'Exit load of 1% if  redeemed within 1 month',
#        'For units in excess of 10% of the investment, 1% will be charged for redemption within 12 Months.',
#        'Exit load 1% if redeemed within 3 months.',
#        'Exit load of 0.5% if redeemed within 30 days.',
#        'Exit load-1%- If redeemed within 15 days from the date of allotment.',
#        'Exit load of 0.25%, if redeemed within 90 days',
#        'Exit load of 0.10%, if redeemed within 30 days',
#        'Exit load of 0.1% if redeemed within 30 days',
#        'Exit load of 0.10%, if redeemed within 3 days.',
#        'Exit load of 1% if redeemed within 3 months',
#        'Exit load of 0.10%, if redeemed within 7 days.',
#        'Exit Load for units in excess of 10% of the investment,1% will be charged for redemption within 1 year.',
#        'Exit load of 0.5%, if redeemed within 30 days.',
#        'Exit load of 1%, if redeemed within 365 days.',
#        'With respect to units not subject to lock-in period and the holding period is less than\r\n3 years: Exit load of 3% if redeemed within 1 year, 2% if redeemed after 1 year but within 2 year, 1% if redeemed after 2 year but within 3 year.',
#        'Exit load of 1% if redeemed wihin 1 year.',
#        'Exit Load for units in excess of 10% of the investment,1% will be charged for redemption within 12 months',
#        'Exit load of 0.15% if redeemed within 30 days.',
#        'Exit load of 0.15%, if redeemed within 30 days.',
#        'Exit load of 1% If redeemed within 15 days.',
#        'Exit Load: 1%- If redeemed on or before 15 days from the date of allotment.',
#        'Exit load of 0.10%, if redeemed within 15 days.',
#        'For Investment above 10%, Exit load of 1% if redeemed within 12 months.',
#        'Exit load of 1% if redeemed wtihin 1 year.',
#        'or units in excess of 10% of the investment,1% will be charged for redemption within 365 days',
#        'Exit load of 2% if redeemed within 365 days, 1% if redeemed after 365 days but within 730 days.',
#        'Exit load of 1% if redeemed within one year',
#        'Exit load of 0.20%, if redeemed within 15 days.'], dtype=object)

# %%
# Get exitload % from text using Regex
def func_exitload(x):
    f = re.findall('(\d+.?\d*)%',x)
    if f: 
        if float(f[-1])>=0.1:
            if float(f[-1]) >= 10:
                return float(1.0)
            else:
                return float(f[-1])
        else:
            return float(max(f))
    else:
        return float(0)

mf['Exit Load Per'] = mf['Exit Load'].apply(func_exitload)

# %%
# Get duration from Text
def func_period(x):
    f = re.findall('(one|\d+) (\w+)',x)
    pro=1
    if f:
        if f[-1][1][0].lower() == 'y':
            pro = 365
        if f[-1][1][0].lower() == 'm':
            pro = 30
        if f[-1][1][0].lower() == 'd':
            pro = 1
        if f[0][0] == 'one':
            return 1*pro
        else:
            return int(f[-1][0])*pro
    else:
        return int('0')
mf['Exit Load Days'] = mf['Exit Load'].apply(func_period)

# %%
mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1113 entries, 0 to 1168
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AMC Name            1111 non-null   object
#  1   AMC Launch Date     1110 non-null   object
#  2   Rank                1086 non-null   float64
#  3   Mutual Fund Name    1113 non-null   object
#  4   AUM                 1102 non-null   float64
#  5   Type                1113 non-null   object
#  6   Scheme Launch Date  1111 non-null   object
#  7   Exit Load           1113 non-null   object
#  8   Expense Ratio       1092 non-null   float64
#  9   Investment Type     1113 non-null   object
#  10  NAV                 1113 non-null   float64
#  11  Minimum Investment  1113 non-null   int64
#  12  Minimum SIP Amount  1104 non-null   float64
#  13  Total Return        1083 non-null   float64
#  14  1m_return           1077 non-null   float64
#  15  1y_return           1003 non-null   float64
#  16  2y_return           933 non-null    float64
#  17  3y_return           866 non-null    float64
#  18  4y_return           808 non-null    float64
#  19  5y_return           713 non-null    float64
#  20  10y_return          534 non-null    float64
#  21  Exit Load Per       1113 non-null   float64
#  22  Exit Load Days      1113 non-null   int64
# dtypes: float64(14), int64(2), object(7)
# memory usage: 208.7+ KB

# %% [markdown]
# ### Dealing Missing values

# %%
mf.drop(mf[(mf['Expense Ratio'].isna()) & (mf['Total Return'].isna())].index,axis=0,inplace=True)

# %%
mf[(mf['Expense Ratio'].isna())].shape
# Out:
# (14, 23)

# %%
mf[(mf['Total Return'].isna())].shape
# Out:
# (23, 23)

# %%
# Based on my Domain Knowledge i decided to fill it with mean value based on type of mutual fund

# %%
mf['Expense Ratio'] = mf.groupby('Type')['Expense Ratio'].transform(lambda x: x.fillna(x.mean()))

# %%
mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1106 entries, 0 to 1167
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AMC Name            1104 non-null   object
#  1   AMC Launch Date     1103 non-null   object
#  2   Rank                1079 non-null   float64
#  3   Mutual Fund Name    1106 non-null   object
#  4   AUM                 1099 non-null   float64
#  5   Type                1106 non-null   object
#  6   Scheme Launch Date  1104 non-null   object
#  7   Exit Load           1106 non-null   object
#  8   Expense Ratio       1106 non-null   float64
#  9   Investment Type     1106 non-null   object
#  10  NAV                 1106 non-null   float64
#  11  Minimum Investment  1106 non-null   int64
#  12  Minimum SIP Amount  1098 non-null   float64
#  13  Total Return        1083 non-null   float64
#  14  1m_return           1077 non-null   float64
#  15  1y_return           1003 non-null   float64
#  16  2y_return           933 non-null    float64
#  17  3y_return           866 non-null    float64
#  18  4y_return           808 non-null    float64
#  19  5y_return           713 non-null    float64
#  20  10y_return          534 non-null    float64
#  21  Exit Load Per       1106 non-null   float64
#  22  Exit Load Days      1106 non-null   int64
# dtypes: float64(14), int64(2), object(7)
# memory usage: 207.4+ KB

# %%
# fill all NAN based on column

# %%
mf.fillna({'Total Return':0,'1m_return':0,'1y_return':0,'2y_return':0,'3y_return':0,
           '4y_return':0,'5y_return':0,'10y_return':0,'Minimum SIP Amount':1,'AUM':0},inplace=True)

# %%
# fill AMC Name based on fund name

# %%
mf.loc[mf['AMC Name'].isna(),['AMC Name']] = 'BNP Paribas'

# %%
mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1106 entries, 0 to 1167
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AMC Name            1106 non-null   object
#  1   AMC Launch Date     1103 non-null   object
#  2   Rank                1079 non-null   float64
#  3   Mutual Fund Name    1106 non-null   object
#  4   AUM                 1106 non-null   float64
#  5   Type                1106 non-null   object
#  6   Scheme Launch Date  1104 non-null   object
#  7   Exit Load           1106 non-null   object
#  8   Expense Ratio       1106 non-null   float64
#  9   Investment Type     1106 non-null   object
#  10  NAV                 1106 non-null   float64
#  11  Minimum Investment  1106 non-null   int64
#  12  Minimum SIP Amount  1106 non-null   float64
#  13  Total Return        1106 non-null   float64
#  14  1m_return           1106 non-null   float64
#  15  1y_return           1106 non-null   float64
#  16  2y_return           1106 non-null   float64
#  17  3y_return           1106 non-null   float64
#  18  4y_return           1106 non-null   float64
#  19  5y_return           1106 non-null   float64
#  20  10y_return          1106 non-null   float64
#  21  Exit Load Per       1106 non-null   float64
#  22  Exit Load Days      1106 non-null   int64
# dtypes: float64(14), int64(2), object(7)
# memory usage: 207.4+ KB

# %%
mf[(mf['AMC Launch Date'].isna()) | (mf['Scheme Launch Date'].isna())]
# Out:
#                 AMC Name           AMC Launch Date  Rank  \
# 335          BNP Paribas                       NaN   NaN
# 542          BNP Paribas                       NaN   NaN
# 600   FRANKLIN_TEMPLETON  1996-02-19T00:00:00.405Z  11.0
# 959            UNION_KBC  2009-12-30T00:00:00.957Z  27.0
# 1040             360 ONE                       NaN   NaN
#
#                                      Mutual Fund Name         AUM    Type  \
# 335          BNP Paribas Multi Cap Fund Direct Growth  561.508000  Equity
# 542         BNP Paribas Short Term Fund Direct Growth  247.544800    Debt
# 600   Franklin India Floating Rate Fund Direct Growth  284.863583    Debt
# 959           Union Money Market Fund Direct   Growth  169.021400    Debt
# 1040            360 ONE FlexiCap Fund Direct   Growth  220.166161  Equity
#
#      Scheme Launch Date                                      Exit Load  \
# 335         02-Jan-2013   Exit load of 1%, if redeemed within 3 months
# 542         02-Jan-2013                                            Nil
# 600                 NaN                                            Nil
# 959                 NaN                                            Nil
# 1040        30-Jun-2023  Exit load of 1%, if redeemed within 365 days.
#
#       Expense Ratio Investment Type  ...  Total Return  1m_return  1y_return  \
# 335            1.01       Multi Cap  ...    302.759117  -4.269030  20.459536
# 542            0.35  Short Duration  ...    105.104671   0.210283   5.315622
# 600            0.20         Floater  ...    100.530870   0.746624   7.916500
# 959            0.29    Money Market  ...     10.221620   0.568667   6.679797
# 1040           0.90       Flexi Cap  ...      1.870000   0.000000   0.000000
#
#       2y_return  3y_return  4y_return   5y_return  10y_return  Exit Load Per  \
# 335   68.449466  70.409096  69.761139  103.621940    0.000000            1.0
# 542   13.589351  23.515512  33.465449   42.400021    0.000000            0.0
# 600   11.559163  17.216791  25.985435   35.740649   92.966536            0.0
# 959    0.000000   0.000000   0.000000    0.000000    0.000000            0.0
# 1040   0.000000   0.000000   0.000000    0.000000    0.000000            1.0
#
#       Exit Load Days
# 335               90
# 542                0
# 600                0
# 959                0
# 1040             365
#
# [5 rows x 23 columns]

# %%
# Fill missing dates manually

# %%
mf.loc[(mf['AMC Launch Date'].isna()),['AMC Launch Date']]=['2007-03-01T00:00:00.405Z','2007-03-01T00:00:00.405Z'
                                                            ,'2008-03-01T00:00:00.405Z']

# %%
mf.loc[(mf['Scheme Launch Date'].isna()),['Scheme Launch Date']]=['30-Jan-2013','26-Aug-2021']

# %%
# Remove unwanted columns

# %%
mf.drop(['Exit Load','Rank'],axis=1,inplace=True)

# %%
mf.drop(mf[mf['Type']=='Commodities'].index, axis=0, inplace=True)

# %% [markdown]
# ### DataType Conversion

# %%
mf['AMC Launch Date'] = mf['AMC Launch Date'].str[:10]

# %%
mf['AMC Launch Date'] = pd.to_datetime(mf['AMC Launch Date'])

# %%
mf['Scheme Launch Date'] = pd.to_datetime(mf['Scheme Launch Date'])

# %%
mf = mf.astype({'Minimum SIP Amount':'int'})

# %%
mf = mf.reset_index(drop=True)

# %%
mf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AMC Name            1104 non-null   object
#  1   AMC Launch Date     1104 non-null   datetime64[ns]
#  2   Mutual Fund Name    1104 non-null   object
#  3   AUM                 1104 non-null   float64
#  4   Type                1104 non-null   object
#  5   Scheme Launch Date  1104 non-null   datetime64[ns]
#  6   Expense Ratio       1104 non-null   float64
#  7   Investment Type     1104 non-null   object
#  8   NAV                 1104 non-null   float64
#  9   Minimum Investment  1104 non-null   int64
#  10  Minimum SIP Amount  1104 non-null   int32
#  11  Total Return        1104 non-null   float64
#  12  1m_return           1104 non-null   float64
#  13  1y_return           1104 non-null   float64
#  14  2y_return           1104 non-null   float64
#  15  3y_return           1104 non-null   float64
#  16  4y_return           1104 non-null   float64
#  17  5y_return           1104 non-null   float64
#  18  10y_return          1104 non-null   float64
#  19  Exit Load Per       1104 non-null   float64
#  20  Exit Load Days      1104 non-null   int64
# dtypes: datetime64[ns](2), float64(12), int32(1), int64(2), object(4)
# memory usage: 176.9+ KB

# %%
mf.to_csv('MF_Data_Clean.csv',index=False)
